# %% [markdown]
# ### MUHAMMAD FIKRI
# ### 2109106010
# ### POSTEST 4

# %% [markdown]
# #### Pertama kita import library yang kita gunakan

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Tamabhkan dataset yang bakal kita gunakan

# %%
dataset_split = pd.read_csv("bike_buyers.csv")

# %%
dataset_split.head()
# Out:
#       ID Marital Status  Gender   Income  Children        Education  \
# 0  12496        Married  Female  40000.0       1.0        Bachelors
# 1  24107        Married    Male  30000.0       3.0  Partial College
# 2  14177        Married    Male  80000.0       5.0  Partial College
# 3  24381         Single     NaN  70000.0       0.0        Bachelors
# 4  25597         Single    Male  30000.0       0.0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 0  Skilled Manual        Yes   0.0        0-1 Miles   Europe  42.0
# 1        Clerical        Yes   1.0        0-1 Miles   Europe  43.0
# 2    Professional         No   2.0        2-5 Miles   Europe  60.0
# 3    Professional        Yes   1.0       5-10 Miles  Pacific  41.0
# 4        Clerical         No   0.0        0-1 Miles   Europe  36.0
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %% [markdown]
# #### cek data

# %%
dataset_split.shape
# Out:
# (810, 13)

# %% [markdown]
# #### Bagi dataset menjadi training set dan testing set (70:30)

# %%
X = dataset_split.iloc[:,:-1]
y = dataset_split.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print("Dimensi X_train: ", X_train.shape)
print("Dimensi X_test: ", X_test.shape)
print("Dimensi y_train: ", y_train.shape)
print("Dimensi y_test: ", y_test.shape)
# Out:
# Dimensi X_train:  (648, 12)
# Dimensi X_test:  (162, 12)
# Dimensi y_train:  (648,)
# Dimensi y_test:  (162,)

# %% [markdown]
# #### Lakukan normalisasi data pada salah satu attribute menggunakan Min Max scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_scaler = MinMaxScaler()

# %%
x_scaled = min_max_scaler.fit_transform(
    dataset_split[['Income','Children','Cars','Age']]
)

# %%
data_normalization = pd.DataFrame(x_scaled)
data_normalization.head()
# Out:
#         0    1     2         3
# 0  0.1875  0.2  0.00  0.265625
# 1  0.1250  0.6  0.25  0.281250
# 2  0.4375  1.0  0.50  0.546875
# 3  0.3750  0.0  0.25  0.250000
# 4  0.1250  0.0  0.00  0.171875

# %%
np.std(dataset_split)
# Out:
# C:\Users\Asus -  GK\venv_A1-21\FIKRI_010\lib\site-packages\numpy\core\fromnumeric.py:3579: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# ID           5326.529622
# Income      32332.440627
# Children        1.617262
# Cars            1.137934
# Age            11.340049
# dtype: float64

# %% [markdown]
# #### Lakukan standarisasi pada dataset

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
x_scaled2 = ss.fit_transform(
    dataset_split[['Income','Children','Cars','Age']]
)

# %%
data_standarization = pd.DataFrame(x_scaled2)
data_standarization.head()
# Out:
#           0         1         2         3
# 0 -0.448158 -0.518996 -1.274349 -0.179221
# 1 -0.757445  0.717662 -0.395563 -0.091038
# 2  0.788989  1.954320  0.483222  1.408073
# 3  0.479702 -1.137325 -0.395563 -0.267404
# 4 -0.757445 -1.137325 -1.274349 -0.708320

# %%
np.std(x_scaled2)
# Out:
# nan

# %% [markdown]
# #### kemudian kita visualisasi data

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dataset_split.ID, dataset_split.Income)
plt.plot(dataset_split.ID, data_normalization[0])
plt.plot(dataset_split.ID, data_standarization)
plt.figure(figsize=(10,10))
plt.show()

# %% [markdown]
# ### Lakukan Data cleaning pada data dengan nilai null
# #### disini saya ,encopy dataset sebelumnya dan saya membuat dataset rusak sendiri
# #### saya buat data rusak pada baris ke 12-25 dan 51-58

# %%
df = pd.read_csv("bike_buyers_rusak.csv")
df.head()
# Out:
#       ID Marital Status  Gender   Income  Children        Education  \
# 0  12496        Married  Female  40000.0       1.0        Bachelors
# 1  24107        Married    Male  30000.0       3.0  Partial College
# 2  14177        Married    Male  80000.0       5.0  Partial College
# 3  24381         Single     NaN  70000.0       0.0        Bachelors
# 4  25597         Single    Male  30000.0       0.0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 0  Skilled Manual        Yes   0.0        0-1 Miles   Europe  42.0
# 1        Clerical        Yes   1.0        0-1 Miles   Europe  43.0
# 2    Professional         No   2.0        2-5 Miles   Europe  60.0
# 3    Professional        Yes   1.0       5-10 Miles  Pacific  41.0
# 4        Clerical         No   0.0        0-1 Miles   Europe  36.0
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
df[8:27]
# Out:
#        ID Marital Status  Gender   Income  Children            Education  \
# 8   22155            NaN    Male  20000.0       2.0  Partial High School
# 9   19280        Married    Male      NaN       2.0      Partial College
# 10  22173        Married  Female      NaN       NaN                  NaN
# 11  12697         Single  Female      NaN       NaN                  NaN
# 12  11434        Married    Male      NaN       NaN                  NaN
# 13  25323        Married    Male      NaN       NaN                  NaN
# 14  23542         Single    Male      NaN       NaN                  NaN
# 15  20870         Single  Female      NaN       NaN                  NaN
# 16  23316         Single    Male      NaN       NaN                  NaN
# 17  12610        Married  Female      NaN       NaN                  NaN
# 18  27183         Single    Male      NaN       NaN                  NaN
# 19  25940         Single    Male      NaN       NaN                  NaN
# ...

# %% [markdown]
# #### cara cek nilai

# %%
df.isna().sum()
# Out:
# ID                   0
# Marital Status      14
# Gender              14
# Income              28
# Children            29
# Education           22
# Occupation          22
# Home Owner          25
# Cars                29
# Commute Distance    22
# Region               0
# Age                  7
# Purchased Bike       0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="mean")

# %%
df["Income"] = imputer.fit_transform(df[["Income"]])

# %%
df.isna().sum()
# Out:
# ID                   0
# Marital Status      14
# Gender              14
# Income               0
# Children            29
# Education           22
# Occupation          22
# Home Owner          25
# Cars                29
# Commute Distance    22
# Region               0
# Age                  7
# Purchased Bike       0
# dtype: int64

# %%
df[49:59]
# Out:
#        ID Marital Status  Gender         Income  Children        Education  \
# 49  14939            NaN     NaN   54143.222506       NaN              NaN
# 50  13826            NaN     NaN   54143.222506       NaN              NaN
# 51  20619            NaN     NaN   54143.222506       NaN              NaN
# 52  12558            NaN     NaN   54143.222506       NaN              NaN
# 53  24871            NaN     NaN   54143.222506       NaN              NaN
# 54  17319            NaN     NaN   54143.222506       NaN              NaN
# 55  28906            NaN     NaN   54143.222506       NaN              NaN
# 56  12808            NaN     NaN   54143.222506       NaN              NaN
# 57  20567        Married    Male  130000.000000       4.0  Partial College
# 58  25502        Married  Female   40000.000000       1.0        Bachelors
#
#         Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 49             NaN        NaN   NaN              NaN   Europe  39.0
# ...

# %%
df.isna().sum()
# Out:
# ID                   0
# Marital Status      14
# Gender              14
# Income               0
# Children            29
# Education           22
# Occupation          22
# Home Owner          25
# Cars                29
# Commute Distance    22
# Region               0
# Age                  7
# Purchased Bike       0
# dtype: int64

# %%
df["Children"] = df["Children"].fillna(df["Children"].mean())

# %%
df.isna().sum()
# Out:
# ID                   0
# Marital Status      14
# Gender              14
# Income               0
# Children             0
# Education           22
# Occupation          22
# Home Owner          25
# Cars                29
# Commute Distance    22
# Region               0
# Age                  7
# Purchased Bike       0
# dtype: int64

# %% [markdown]
# ## menangani nilai duplikat
# #### dsini saya juga membuagt nilai duplikat sendiri pada baris ke 75-82

# %%
df[df.duplicated()]
# Out:
#        ID Marital Status  Gender   Income  Children        Education  \
# 74  26956         Single  Female  20000.0       0.0  Partial College
# 75  26956         Single  Female  20000.0       0.0  Partial College
# 76  26956         Single  Female  20000.0       0.0  Partial College
# 77  26956         Single  Female  20000.0       0.0  Partial College
# 78  26956         Single  Female  20000.0       0.0  Partial College
# 79  26956         Single  Female  20000.0       0.0  Partial College
# 80  26956         Single  Female  20000.0       0.0  Partial College
#
#    Occupation Home Owner  Cars Commute Distance  Region   Age Purchased Bike
# 74     Manual         No   1.0        2-5 Miles  Europe  36.0            Yes
# 75     Manual         No   1.0        2-5 Miles  Europe  36.0            Yes
# 76     Manual         No   1.0        2-5 Miles  Europe  36.0            Yes
# 77     Manual         No   1.0        2-5 Miles  Europe  36.0            Yes
# ...

# %% [markdown]
# ### cara menampilkan nilai duplicate dengan angka

# %%
df.duplicated().sum()
# Out:
# 7

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### dan nilai duplikat sudah 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Marital Status, Gender, Income, Children, Education, Occupation, Home Owner, Cars, Commute Distance, Region, Age, Purchased Bike]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Lakukan one hot encoding pada dataset yang kalian miliki.

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onehotencoder = OneHotEncoder(sparse=False)

# %%
Gender_encoded2 = onehotencoder.fit_transform(df[["Gender"]])

# %%
df2 = pd.DataFrame(Gender_encoded2)
df = df.join(df2)

# %%
df.head(10)
# Out:
#       ID Marital Status  Gender         Income  Children            Education  \
# 0  12496        Married  Female   40000.000000       1.0            Bachelors
# 1  24107        Married    Male   30000.000000       3.0      Partial College
# 2  14177        Married    Male   80000.000000       5.0      Partial College
# 3  24381         Single     NaN   70000.000000       0.0            Bachelors
# 4  25597         Single    Male   30000.000000       0.0            Bachelors
# 5  13507        Married  Female   10000.000000       2.0      Partial College
# 6  27974         Single    Male  160000.000000       2.0          High School
# 7  19364        Married    Male   40000.000000       1.0            Bachelors
# 8  22155            NaN    Male   20000.000000       2.0  Partial High School
# 9  19280        Married    Male   54143.222506       2.0      Partial College
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# ...

# %%
df[10:50]
# Out:
#        ID Marital Status  Gender         Income  Children  \
# 10  22173        Married  Female   54143.222506  1.824584
# 11  12697         Single  Female   54143.222506  1.824584
# 12  11434        Married    Male   54143.222506  1.824584
# 13  25323        Married    Male   54143.222506  1.824584
# 14  23542         Single    Male   54143.222506  1.824584
# 15  20870         Single  Female   54143.222506  1.824584
# 16  23316         Single    Male   54143.222506  1.824584
# 17  12610        Married  Female   54143.222506  1.824584
# 18  27183         Single    Male   54143.222506  1.824584
# 19  25940         Single    Male   54143.222506  1.824584
# 20  25598        Married  Female   54143.222506  1.824584
# 21  21564         Single  Female   54143.222506  1.824584
# 22  19193         Single    Male   54143.222506  1.824584
# 23  26412        Married  Female   54143.222506  1.824584
# 24  27184         Single    Male   40000.000000  2.000000
# ...

# %% [markdown]
# ## Ganti tipe data salah satu attribute angka
# ### saya akan mengubah tipe data float64 ke string

# %%
import pandas as pd

# %%
dataset_split = pd.read_csv("bike_buyers.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 803 entries, 0 to 809
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                803 non-null    int64
#  1   Marital Status    789 non-null    object
#  2   Gender            789 non-null    object
#  3   Income            803 non-null    float64
#  4   Children          803 non-null    float64
#  5   Education         781 non-null    object
#  6   Occupation        781 non-null    object
#  7   Home Owner        778 non-null    object
#  8   Cars              774 non-null    float64
#  9   Commute Distance  781 non-null    object
#  10  Region            803 non-null    object
#  11  Age               796 non-null    float64
#  12  Purchased Bike    803 non-null    object
#  13  0                 796 non-null    float64
#  14  1                 796 non-null    float64
#  15  2                 796 non-null    float64
# ...

# %%
df['Age'] = df['Age'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 803 entries, 0 to 809
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                803 non-null    int64
#  1   Marital Status    789 non-null    object
#  2   Gender            789 non-null    object
#  3   Income            803 non-null    float64
#  4   Children          803 non-null    float64
#  5   Education         781 non-null    object
#  6   Occupation        781 non-null    object
#  7   Home Owner        778 non-null    object
#  8   Cars              774 non-null    float64
#  9   Commute Distance  781 non-null    object
#  10  Region            803 non-null    object
#  11  Age               796 non-null    string
#  12  Purchased Bike    803 non-null    object
#  13  0                 796 non-null    float64
#  14  1                 796 non-null    float64
#  15  2                 796 non-null    float64
# ...
